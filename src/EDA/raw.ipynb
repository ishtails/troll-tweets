# %% [markdown]
# # EDA - Raw Data

# %%
import pandas as pd

raw_data = pd.read_csv(r"d:\Code\ml\troll-tweets\data\raw\IRAhandle_tweets_1.csv")
raw_data.head()
# Out:
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#       publish_date   harvested_date  following  followers  updates  ...  \
# 0  10/1/2017 19:58  10/1/2017 19:59       1052       9636      253  ...
# 1  10/1/2017 22:43  10/1/2017 22:43       1054       9637      254  ...
# 2  10/1/2017 22:50  10/1/2017 22:51       1054       9637      255  ...
# ...

# %%
# keep only the columns we need
keep_cols = [
        "content",
        "region",
        "language",
        "publish_date",
        "following",
        "followers",
        "updates",
        "account_type",
        "retweet",
        "account_category",
    ]

df = raw_data[keep_cols]
print(df.head())
# Out:
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#       publish_date  following  followers  updates account_type  retweet  \
# 0  10/1/2017 19:58       1052       9636      253        Right        0
# 1  10/1/2017 22:43       1054       9637      254        Right        0
# 2  10/1/2017 22:50       1054       9637      255        Right        1
# 3  10/1/2017 23:52       1062       9642      256        Right        0
# 4   10/1/2017 2:13       1050       9645      246        Right        1
#
#   account_category
# 0       RightTroll
# 1       RightTroll
# 2       RightTroll
# 3       RightTroll
# ...

# %%
# info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243891 entries, 0 to 243890
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   content           243891 non-null  object
#  1   region            243853 non-null  object
#  2   language          243891 non-null  object
#  3   publish_date      243891 non-null  object
#  4   following         243891 non-null  int64
#  5   followers         243891 non-null  int64
#  6   updates           243891 non-null  int64
#  7   account_type      243891 non-null  object
#  8   retweet           243891 non-null  int64
#  9   account_category  243891 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 18.6+ MB

# %%
# describe the data
f.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # describe the data
# ----> 2 f.describe()
#
# NameError: name 'f' is not defined

# %%
# number of null values
df.isnull().sum()
# Out:
# content              0
# region              38
# language             0
# publish_date         0
# following            0
# followers            0
# updates              0
# account_type         0
# retweet              0
# account_category     0
# dtype: int64

# %%
# percentage of null values
df.isnull().sum() / len(df)
# Out:
# content             0.000000
# region              0.000156
# language            0.000000
# publish_date        0.000000
# following           0.000000
# followers           0.000000
# updates             0.000000
# account_type        0.000000
# retweet             0.000000
# account_category    0.000000
# dtype: float64

# %%
# followers to following ratio
derived = pd.DataFrame()
derived["followers_to_following_ratio"] = df["followers"] / df["following"]

derived.head()
# Out:
#    followers_to_following_ratio
# 0                      9.159696
# 1                      9.143264
# 2                      9.143264
# 3                      9.079096
# 4                      9.185714

# %%
# get year, month, day, hour, minute, second from publish_date
derived['date'] = pd.to_datetime(df['publish_date'], errors='coerce')
derived["year"] = derived["date"].dt.year
derived["month"] = derived["date"].dt.month
derived["day"] = derived["date"].dt.day
derived["hour"] = derived["date"].dt.hour
derived["minute"] = derived["date"].dt.minute
derived["second"] = derived["date"].dt.second

derived.head()
# Out:
#    followers_to_following_ratio                date  year  month  day  hour  \
# 0                      9.159696 2017-10-01 19:58:00  2017     10    1    19
# 1                      9.143264 2017-10-01 22:43:00  2017     10    1    22
# 2                      9.143264 2017-10-01 22:50:00  2017     10    1    22
# 3                      9.079096 2017-10-01 23:52:00  2017     10    1    23
# 4                      9.185714 2017-10-01 02:13:00  2017     10    1     2
#
#    minute  second
# 0      58       0
# 1      43       0
# 2      50       0
# 3      52       0
# 4      13       0
